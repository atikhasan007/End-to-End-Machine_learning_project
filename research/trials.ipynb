# %%
import os

# %%
# python confix box

d = {
    "key1": "value1",
    "key2": "value2",
    
}

# %%
d['key1']
# Out:
# 'value1'

# %%
d['key2']
# Out:
# 'value2'

# %%
d.items
# Out:
# <function dict.items>

# %%
d.key1 # not working so we are using configbox
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
pip install python-box==6.0.2
# Out:
# Collecting python-box==6.0.2
#   Using cached python_box-6.0.2-cp38-cp38-win_amd64.whl.metadata (7.7 kB)
# Downloading python_box-6.0.2-cp38-cp38-win_amd64.whl (944 kB)
#    ---------------------------------------- 0.0/944.1 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/944.1 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/944.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 944.1/944.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: python-box
# Successfully installed python-box-6.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox

# %%
# python confix box

d1 = ConfigBox({
    "key1": "value1",
    "key2": "value2",
    
})

# %%
type(d)
# Out:
# dict

# %%
type(d1)
# Out:
# box.config_box.ConfigBox

# %%
d1.key1
# Out:
# 'value1'

# %%
d1.key2
# Out:
# 'value2'

# %%
# ensure annotation demo

def get_product(x:int,y:int) -> int:

    return x * y

# %%
get_product(x=5,y=6)
# Out:
# 30

# %%
get_product(x=2,y="3") # so it is worg
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=5,y=6)
# Out:
# 30

# %%
get_product(x=2,y="3") # so it is worg
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 get_product(x=2,y="3") # so it is worg
#
# File c:\Users\Hp\anaconda3\envs\MLproj\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001CF3B14CF70> does not match annotation type <class 'int'>
